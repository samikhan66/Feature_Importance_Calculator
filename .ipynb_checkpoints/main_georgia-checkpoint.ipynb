# %%
# Problem: Build a model that explains how some of the indicators influence energy burden.
# For this notebook, I have only included the rows for the state of Colorado.
import os
import random

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedKFold
from sklearn.tree import DecisionTreeRegressor
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
from xgboost import XGBRegressor

import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

# %%
missing_values = ["n/a", "na", "--"]
# Read csv
df = pd.read_csv("interview_sample_data.csv", na_values=missing_values)
# Include rows for the state of Colorado only
df = df[df.state == "GA"]
# Find the statistical attributes of the dataframe
df.describe()
# Out:
#                 id2         year  percent_renter  percent_asian  \
# count  1.388000e+03  1388.000000     1379.000000    1387.000000
# mean   1.310773e+10  2014.500000        0.485578       0.052345
# std    1.576575e+07     1.118437        0.241590       0.075690
# min    1.308902e+10  2013.000000        0.010000       0.000000
# 25%    1.308902e+10  2013.750000        0.294000       0.002000
# 50%    1.312100e+10  2014.500000        0.492000       0.026000
# 75%    1.312101e+10  2015.250000        0.665500       0.067000
# max    1.312101e+10  2016.000000        1.000000       0.478000
#
#        percent_black  percent_hispanic  percent_multifamily_housing  \
# count    1387.000000       1387.000000                  1382.000000
# mean        0.483236          0.081218                     0.410534
# std         0.366050          0.122876                     0.285310
# min         0.000000          0.000000                     0.000000
# 25%         0.112000          0.018000                     0.166883
# 50%         0.428000          0.042000                     0.385671
# 75%         0.893000          0.080000                     0.651174
# max         1.000000          0.878000                     1.000000
#
#        eviction_rate  poverty_rate  median_income  avg_cost_electricity  \
# count    1388.000000   1388.000000    1376.000000           1388.000000
# mean        5.333336     16.351960   60049.793605           1435.972529
# std         5.871455     14.562441   35114.716833           1927.474868
# min         0.000000      0.000000    6815.000000          -9999.000000
# 25%         1.330000      4.720000   33777.000000           1239.165000
# 50%         3.205000     11.970000   51321.500000           1612.000000
# 75%         8.030000     25.980000   75198.000000           2012.000000
# max       100.000000     86.340000  187750.000000           6588.000000
#
#        avg_cost_gas  avg_cost_water  asthma_rate
# count   1388.000000     1388.000000   180.000000
# mean     868.315029      383.275490     9.760278
# std     1787.551502     1679.118474     2.121615
# min    -9999.000000    -9999.000000     6.700000
# 25%      794.487500      419.265000     7.800000
# 50%     1039.070000      592.990000     9.100000
# 75%     1356.132500      780.175000    11.700000
# max     5844.000000     3003.000000    16.100000

# %%
# Find null values 
df.isnull().sum()
# Result shows that 85% of asthma_rate are Nans
# Out:
# id2                               0
# geography                         0
# year                              0
# state                             0
# percent_renter                    9
# percent_asian                     1
# percent_black                     1
# percent_hispanic                  1
# percent_multifamily_housing       6
# eviction_rate                     0
# poverty_rate                      0
# median_income                    12
# avg_cost_electricity              0
# avg_cost_gas                      0
# avg_cost_water                    0
# asthma_rate                    1208
# dtype: int64

# %%
# Visualize the attributes to get a sense of the data
df.hist(bins=50, figsize=(20, 15))
plt.show()

# The histograms portray some of the standardizations that need to take place:
# 1. The indicators need to be converted to the same units (decimals).
# 2. The negative values in average cost columns need to be replaced with NaN .

# %%
# Replace negative numbers with NaN
avg_values_list = ["avg_cost_electricity", "avg_cost_gas", "avg_cost_water"]
df[avg_values_list] = df[avg_values_list].mask(df[avg_values_list] < 0)

# %%
# Drop rows with na values since not too many. 
df = df.dropna()
print(df)
# Out:
#               id2                                    geography  year state  \
# 1120  13089020100     Census Tract 201, DeKalb County, Georgia  2015    GA
# 1121  13089020200     Census Tract 202, DeKalb County, Georgia  2015    GA
# 1122  13089020300     Census Tract 203, DeKalb County, Georgia  2015    GA
# 1123  13089020400     Census Tract 204, DeKalb County, Georgia  2015    GA
# 1125  13089020600     Census Tract 206, DeKalb County, Georgia  2015    GA
# ...           ...                                          ...   ...   ...
# 1460  13121011624  Census Tract 116.24, Fulton County, Georgia  2015    GA
# 1461  13121011625  Census Tract 116.25, Fulton County, Georgia  2015    GA
# 1462  13121011626  Census Tract 116.26, Fulton County, Georgia  2015    GA
# 1463  13121011800     Census Tract 118, Fulton County, Georgia  2015    GA
# 1465  13121012000     Census Tract 120, Fulton County, Georgia  2015    GA
#
#       percent_renter  percent_asian  percent_black  percent_hispanic  \
# 1120           0.219          0.037          0.020             0.040
# 1121           0.443          0.014          0.058             0.059
# 1122           0.336          0.027          0.050             0.045
# 1123           0.399          0.048          0.046             0.041
# 1125           0.598          0.030          0.560             0.032
# ...              ...            ...            ...               ...
# 1460           0.053          0.204          0.066             0.021
# 1461           0.370          0.294          0.114             0.032
# 1462           0.436          0.254          0.211             0.095
# 1463           0.940          0.048          0.707             0.061
# 1465           0.761          0.036          0.898             0.019
#
#       percent_multifamily_housing  eviction_rate  poverty_rate  median_income  \
# 1120                     0.137203           3.59          3.85       153177.0
# 1121                     0.441558           0.33          1.42       102829.0
# 1122                     0.248642           0.90          4.80       101875.0
# 1123                     0.509944           0.17          3.27        78897.0
# 1125                     0.512488           3.51         34.21        38452.0
# ...                           ...            ...           ...            ...
# 1460                     0.000000           0.00          0.98       166477.0
# 1461                     0.246451           1.39          5.81       106620.0
# 1462                     0.299536           1.03          8.13        78152.0
# 1463                     0.811176           3.79         51.26        10000.0
# 1465                     0.649066           6.02         50.65        17558.0
#
#       avg_cost_electricity  avg_cost_gas  avg_cost_water  asthma_rate
# 1120               1605.11       1178.73          616.91          7.4
# 1121               3130.26       3051.63          936.22          7.8
# 1122               3130.26       3051.63          936.22          7.9
# 1123               1875.37        931.79          286.10          7.7
# 1125               1860.00       1860.00         1138.00         10.2
# ...                    ...           ...             ...          ...
# 1460               2840.95        774.56          663.49          7.6
# 1461               1807.31        748.78          477.32          8.0
# 1462               1952.25        919.07          548.23          8.1
# 1463               1011.36       1022.40          721.18         12.5
# 1465               2499.92       1129.77         1379.40         13.0
#
# [173 rows x 16 columns]

# %%
# 1. Drop id2 since it is essentially the same thing as geography.
# 2. Drop state because it is a sub category of geography.
# 3. Drop year because unnecessary.
# 4. Drop asthma_rate since ~85% values are NaN.
df = df.drop(['id2', 'geography','year', 'state','asthma_rate'], axis = 1)

# %%
# Convert eviction, poverty rate to decimal
df[["eviction_rate", "poverty_rate"]] = df[["eviction_rate", "poverty_rate"]] / 100

# Create energy burden column i.e. (avg cost of electricity + avg cost of gas) / median income
df["energy_burden"] = (df.loc[:, [avg_values_list[0], avg_values_list[1]]].sum(axis=1)) / df["median_income"]

# Replace median income with log(median income) to break linearity b/w income and energy burden
df["median_income"] = np.log10(df["median_income"])

# %%
# Heatmap to visualize the correlated and uncorrelated data
corr_ = df.corr()["energy_burden"].sort_values(ascending = False)
corr_ = df.corr()
# visualise the data with seaborn
mask = np.triu(np.ones_like(corr_, dtype=bool))
sns.set_style(style='white')
f, ax = plt.subplots(figsize=(12, 15))
cmap = sns.diverging_palette(10, 250, as_cmap=True)
sns.heatmap(corr_, mask=mask, cmap=cmap,
            square=True, annot=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
plt.show()

# %%
# Use Recursive Feature Elimination to filter out features that are closely correlated and features 
# that have very low correlation with the target variable

# Define X(exogenous) and y(endogenous) variables that will be fed into the recursive elimination algorithm.
X = df.drop(['energy_burden'], axis=1)
y = df['energy_burden']
# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Use automatic feature selection instead of manually specifying number of features.
rfecv = RFECV(estimator=DecisionTreeRegressor())
model = DecisionTreeRegressor()
# Pipeline — since we’ll perform some cross-validation. It’s best practice in order to avoid data leakage.
pipeline = Pipeline(steps=[('Feature Selection',rfecv),('Model',model)])
# Evaluate model
cv = RepeatedKFold(n_splits=10, n_repeats=5, random_state=42)
n_scores = cross_val_score(pipeline, X_train, y_train, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1, error_score='raise')
# Report performance
print('MAE: %.3f (%.3f)' % (np.mean(n_scores), np.std(n_scores)))
pipeline.fit(X_train, y_train)
print("Optimal number of features : %d" % rfecv.n_features_)
print('\n')
# Find the 'Ranks' of each feature and sort these values by individual 'Rank'.
# Rank is the order of importance i.e. Rank 1 (most important), Rank 2 (second order of importance) and so on.
rf_df = pd.DataFrame(rfecv.ranking_,index=X.columns,columns=['Rank']).sort_values(by='Rank',ascending=True)
print(rf_df.head(rfecv.n_features_))
# Out:
# MAE: -0.008 (0.004)
# Optimal number of features : 6
#
#
#                       Rank
# percent_renter           1
# eviction_rate            1
# median_income            1
# avg_cost_electricity     1
# avg_cost_gas             1
# avg_cost_water           1

# %%
# Recursive feature elimination resulted that the optimal number of features is six. 
X = df.drop(['percent_asian', 'percent_hispanic', 'percent_multifamily_housing', 'poverty_rate',
             'percent_black', 'energy_burden'], axis=1)
y = df['energy_burden']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Split dataset to train and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
#Find existing columns
cols = [col for col in X.columns]
print(cols)
# Out:
# ['percent_renter', 'eviction_rate', 'median_income', 'avg_cost_electricity', 'avg_cost_gas', 'avg_cost_water']

# %%
def importance_fn(model):
    """
    Parameters
    ----------
        model : Model that has been fitted on the training data.

    Returns
    -------
        feature_importance: Calculate importance scores of each feature that
        the energy burden depends on.
    """
    # get importance
    importance = model.feature_importances_
    # summarize feature importance
    feature_importance = [value for value in importance]

    return feature_importance

# %%
def random_forest():    
    """
    Find the feature importance that random forest predicts.
    Decision Trees are prone to overfitting so Random Forest algorithm was implemented.
    RF has enough capacity to completely memorize the training set
    but it can still generalize well enough due to built-in bagging of random forests.

    Returns
    -------
        rf_feature_importance : Calculate importance scores of each feature that
        the energy burden depends on.
        rf_train_accuracy : Accuracy of the Random Forest model on training data.
        rf_test_accuracy : Accuracy of the Random Forest model on test data.
    """

    model = RandomForestRegressor()
    # fit the model
    model.fit(X_train, y_train)
    rf_train_accuracy = model.score(X_train, y_train)
    rf_test_accuracy = model.score(X_test, y_test)
    rf_feature_importance = importance_fn(model)

    return importance_fn(model), rf_train_accuracy, rf_test_accuracy

# %%
        
def plot_features(model=""):    
    """
    Plot feature importances predicted by selected algorithm while plotting it against features.
    """
    try:
        if model == "random_forest":
            rf_feature_importance, _, _ = random_forest()
            # plot feature importance for random forest
            plt.figure(figsize=(20, 8))
            plt.title("Feature Importance for Random Forest")
            plt.xlabel("Features")
            plt.ylabel("Importance")
            plt.bar([col for col in cols], [x for x in rf_feature_importance])
            plt.show()
        elif model == "xgboost":
            xgboost_feature_importance, _, _ = xg_boost()
            # plot feature importance
            plt.figure(figsize=(20, 8))
            plt.title("Feature Importance for XGBoost")
            plt.xlabel("Features")
            plt.ylabel("Importance")
            plt.bar([col for col in cols], [x for x in xgboost_feature_importance])
            plt.show()
        elif model == "dnn":
            # plot feature importance
            dnn_feature_importance = dnn()
            plt.figure(figsize=(20, 8))
            plt.title("Feature Importance for Deep Neural Network")
            plt.xlabel("Features")
            plt.ylabel("Importance")
            plt.bar([col for col in cols], [x for x in dnn_feature_importance])
            plt.show()
        elif model == "average":
            rf_feature_importance, _, _ = random_forest()
            xgboost_feature_importance, _, _ = xg_boost()
            dnn_feature_importance = dnn()
            avg_importance = [np.mean(i) for i in zip(rf_feature_importance, 
                                                      xgboost_feature_importance, 
                                                      dnn_feature_importance)]
            plt.figure(figsize=(20, 8))
            plt.title("Average Feature Importance of all models")
            plt.xlabel("Features")
            plt.ylabel("Importance")
            plt.bar([col for col in cols], [x for x in avg_importance])

            plt.show()
        else:
            pass
    except Exception as e:
        print(e)
plot_features()

# %%
# Plot feature importances predicted by Random Forest algorithm while plotting it against features.
plot_features("random_forest")

# %%
def xg_boost():    
    """
    XGBoost for feature importance on a regression problem.

    Just like gradient boosting, XGBoost comprises an ensemble method
    XGBoost comes with an additional custom regularization term in the
    objective function which is why it outperforms other implementations
    of gradient tree boosting.

    Returns
    -------
        xgboost_feature_importance : Calculate importance scores of each feature that
        the energy burden depends on.
        xgboost_train_accuracy : Accuracy of the XGBoost model on training data.
        xgboost_test_accuracy : Accuracy of the XGBoost model on test data.
    """
    # define the model
    model = XGBRegressor()
    # fit the model
    model.fit(X_train, y_train)
    xgboost_train_accuracy = model.score(X_train, y_train)
    xgboost_test_accuracy = model.score(X_test, y_test)

    xgboost_feature_importance = importance_fn(model)
    
    return xgboost_feature_importance, xgboost_train_accuracy, xgboost_test_accuracy

# %%
# Plot feature importances predicted by XGBoost algorithm while plotting it against features.
plot_features("xgboost")

# %%
# Scale variables
scaler = StandardScaler()
scaled_train = scaler.fit_transform(X_train)
scaled_test = scaler.transform(X_test)
# Utility functions to scale the target
mean_train = y_train.mean()
std_train = y_train.std()

# %%
def scale_target(y, mean, std):
    """Use to scale the target variable using the formula => (value - mean)/standard deviation.
    We need to performing this scaling in order to feed it while training the Neural Network"""
    return np.asarray((y - mean)/std)

def reverse_target(pred, mean, std):
     #Use to reverse the scaled target variable using the formula => Predicted_value*standard deviation + mean
     #We need to perform this rescaling in order to compare the predictions"""
    return np.asarray(pred*std + mean)

# %%
# Set random seed to 42 so that the same set is selected every time
tf.random.set_seed(42)
os.environ['PYTHONHASHSEED'] = str(42)
np.random.seed(42)
random.seed(42)

# %%
# Build tensorflow session
session_conf = tf.compat.v1.ConfigProto(
    intra_op_parallelism_threads=1,
    inter_op_parallelism_threads=1
)
sess = tf.compat.v1.Session(
    graph=tf.compat.v1.get_default_graph(),
    config=session_conf
)
tf.compat.v1.keras.backend.set_session(sess)

# %%
# Define NN structure
inp = Input(shape=(scaled_train.shape[1],))
x = Dense(500, activation='relu')(inp)
x = Dense(500, activation='relu')(inp)
x = Dense(500, activation='relu')(inp)
x = Dense(250, activation='relu')(inp)
x = Dense(25, activation='relu')(x)
out = Dense(1)(x)
model = Model(inp, out)

# %%
# Compile and fit model
model.compile(optimizer='adam', loss='mse', metrics=['mean_squared_error'])
model.fit(scaled_train, scale_target(y_train, mean_train, std_train) , epochs=100, batch_size=64 ,verbose=2)
# Out:
# Epoch 1/100
# 3/3 - 0s - loss: 1.0752 - mean_squared_error: 1.0752
# Epoch 2/100
# 3/3 - 0s - loss: 0.7866 - mean_squared_error: 0.7866
# Epoch 3/100
# 3/3 - 0s - loss: 0.5951 - mean_squared_error: 0.5951
# Epoch 4/100
# 3/3 - 0s - loss: 0.4531 - mean_squared_error: 0.4531
# Epoch 5/100
# 3/3 - 0s - loss: 0.3474 - mean_squared_error: 0.3474
# Epoch 6/100
# 3/3 - 0s - loss: 0.2667 - mean_squared_error: 0.2667
# Epoch 7/100
# 3/3 - 0s - loss: 0.2147 - mean_squared_error: 0.2147
# Epoch 8/100
# 3/3 - 0s - loss: 0.1768 - mean_squared_error: 0.1768
# Epoch 9/100
# 3/3 - 0s - loss: 0.1519 - mean_squared_error: 0.1519
# Epoch 10/100
# 3/3 - 0s - loss: 0.1305 - mean_squared_error: 0.1305
# Epoch 11/100
# 3/3 - 0s - loss: 0.1186 - mean_squared_error: 0.1186
# Epoch 12/100
# 3/3 - 0s - loss: 0.1069 - mean_squared_error: 0.1069
# Epoch 13/100
# 3/3 - 0s - loss: 0.0991 - mean_squared_error: 0.0991
# Epoch 14/100
# 3/3 - 0s - loss: 0.1034 - mean_squared_error: 0.1034
# Epoch 15/100
# 3/3 - 0s - loss: 0.1033 - mean_squared_error: 0.1033
# Epoch 16/100
# 3/3 - 0s - loss: 0.0971 - mean_squared_error: 0.0971
# Epoch 17/100
# 3/3 - 0s - loss: 0.0846 - mean_squared_error: 0.0846
# Epoch 18/100
# 3/3 - 0s - loss: 0.0722 - mean_squared_error: 0.0722
# Epoch 19/100
# 3/3 - 0s - loss: 0.0617 - mean_squared_error: 0.0617
# Epoch 20/100
# 3/3 - 0s - loss: 0.0541 - mean_squared_error: 0.0541
# Epoch 21/100
# 3/3 - 0s - loss: 0.0471 - mean_squared_error: 0.0471
# Epoch 22/100
# 3/3 - 0s - loss: 0.0489 - mean_squared_error: 0.0489
# Epoch 23/100
# 3/3 - 0s - loss: 0.0557 - mean_squared_error: 0.0557
# Epoch 24/100
# 3/3 - 0s - loss: 0.0587 - mean_squared_error: 0.0587
# Epoch 25/100
# 3/3 - 0s - loss: 0.0563 - mean_squared_error: 0.0563
# Epoch 26/100
# 3/3 - 0s - loss: 0.0501 - mean_squared_error: 0.0501
# Epoch 27/100
# 3/3 - 0s - loss: 0.0430 - mean_squared_error: 0.0430
# Epoch 28/100
# 3/3 - 0s - loss: 0.0381 - mean_squared_error: 0.0381
# Epoch 29/100
# 3/3 - 0s - loss: 0.0341 - mean_squared_error: 0.0341
# Epoch 30/100
# 3/3 - 0s - loss: 0.0313 - mean_squared_error: 0.0313
# Epoch 31/100
# 3/3 - 0s - loss: 0.0297 - mean_squared_error: 0.0297
# Epoch 32/100
# 3/3 - 0s - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 33/100
# 3/3 - 0s - loss: 0.0303 - mean_squared_error: 0.0303
# Epoch 34/100
# 3/3 - 0s - loss: 0.0315 - mean_squared_error: 0.0315
# Epoch 35/100
# 3/3 - 0s - loss: 0.0302 - mean_squared_error: 0.0302
# Epoch 36/100
# 3/3 - 0s - loss: 0.0318 - mean_squared_error: 0.0318
# Epoch 37/100
# 3/3 - 0s - loss: 0.0396 - mean_squared_error: 0.0396
# Epoch 38/100
# 3/3 - 0s - loss: 0.0410 - mean_squared_error: 0.0410
# Epoch 39/100
# 3/3 - 0s - loss: 0.0390 - mean_squared_error: 0.0390
# Epoch 40/100
# 3/3 - 0s - loss: 0.0332 - mean_squared_error: 0.0332
# Epoch 41/100
# 3/3 - 0s - loss: 0.0364 - mean_squared_error: 0.0364
# Epoch 42/100
# 3/3 - 0s - loss: 0.0378 - mean_squared_error: 0.0378
# Epoch 43/100
# 3/3 - 0s - loss: 0.0274 - mean_squared_error: 0.0274
# Epoch 44/100
# 3/3 - 0s - loss: 0.0241 - mean_squared_error: 0.0241
# Epoch 45/100
# 3/3 - 0s - loss: 0.0272 - mean_squared_error: 0.0272
# Epoch 46/100
# 3/3 - 0s - loss: 0.0291 - mean_squared_error: 0.0291
# Epoch 47/100
# 3/3 - 0s - loss: 0.0282 - mean_squared_error: 0.0282
# Epoch 48/100
# 3/3 - 0s - loss: 0.0259 - mean_squared_error: 0.0259
# Epoch 49/100
# 3/3 - 0s - loss: 0.0252 - mean_squared_error: 0.0252
# Epoch 50/100
# 3/3 - 0s - loss: 0.0246 - mean_squared_error: 0.0246
# Epoch 51/100
# 3/3 - 0s - loss: 0.0230 - mean_squared_error: 0.0230
# Epoch 52/100
# 3/3 - 0s - loss: 0.0215 - mean_squared_error: 0.0215
# Epoch 53/100
# 3/3 - 0s - loss: 0.0201 - mean_squared_error: 0.0201
# Epoch 54/100
# 3/3 - 0s - loss: 0.0188 - mean_squared_error: 0.0188
# Epoch 55/100
# 3/3 - 0s - loss: 0.0179 - mean_squared_error: 0.0179
# Epoch 56/100
# 3/3 - 0s - loss: 0.0173 - mean_squared_error: 0.0173
# Epoch 57/100
# 3/3 - 0s - loss: 0.0169 - mean_squared_error: 0.0169
# Epoch 58/100
# 3/3 - 0s - loss: 0.0163 - mean_squared_error: 0.0163
# Epoch 59/100
# 3/3 - 0s - loss: 0.0161 - mean_squared_error: 0.0161
# Epoch 60/100
# 3/3 - 0s - loss: 0.0157 - mean_squared_error: 0.0157
# Epoch 61/100
# 3/3 - 0s - loss: 0.0150 - mean_squared_error: 0.0150
# Epoch 62/100
# 3/3 - 0s - loss: 0.0143 - mean_squared_error: 0.0143
# Epoch 63/100
# 3/3 - 0s - loss: 0.0141 - mean_squared_error: 0.0141
# Epoch 64/100
# 3/3 - 0s - loss: 0.0140 - mean_squared_error: 0.0140
# Epoch 65/100
# 3/3 - 0s - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 66/100
# 3/3 - 0s - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 67/100
# 3/3 - 0s - loss: 0.0119 - mean_squared_error: 0.0119
# Epoch 68/100
# 3/3 - 0s - loss: 0.0131 - mean_squared_error: 0.0131
# Epoch 69/100
# 3/3 - 0s - loss: 0.0129 - mean_squared_error: 0.0129
# Epoch 70/100
# 3/3 - 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 71/100
# 3/3 - 0s - loss: 0.0110 - mean_squared_error: 0.0110
# Epoch 72/100
# 3/3 - 0s - loss: 0.0106 - mean_squared_error: 0.0106
# Epoch 73/100
# 3/3 - 0s - loss: 0.0107 - mean_squared_error: 0.0107
# Epoch 74/100
# 3/3 - 0s - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 75/100
# 3/3 - 0s - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 76/100
# 3/3 - 0s - loss: 0.0109 - mean_squared_error: 0.0109
# Epoch 77/100
# 3/3 - 0s - loss: 0.0105 - mean_squared_error: 0.0105
# Epoch 78/100
# 3/3 - 0s - loss: 0.0101 - mean_squared_error: 0.0101
# Epoch 79/100
# 3/3 - 0s - loss: 0.0094 - mean_squared_error: 0.0094
# Epoch 80/100
# 3/3 - 0s - loss: 0.0092 - mean_squared_error: 0.0092
# Epoch 81/100
# 3/3 - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 82/100
# 3/3 - 0s - loss: 0.0097 - mean_squared_error: 0.0097
# Epoch 83/100
# 3/3 - 0s - loss: 0.0114 - mean_squared_error: 0.0114
# Epoch 84/100
# 3/3 - 0s - loss: 0.0125 - mean_squared_error: 0.0125
# Epoch 85/100
# 3/3 - 0s - loss: 0.0112 - mean_squared_error: 0.0112
# Epoch 86/100
# 3/3 - 0s - loss: 0.0090 - mean_squared_error: 0.0090
# Epoch 87/100
# 3/3 - 0s - loss: 0.0091 - mean_squared_error: 0.0091
# Epoch 88/100
# 3/3 - 0s - loss: 0.0273 - mean_squared_error: 0.0273
# Epoch 89/100
# 3/3 - 0s - loss: 0.0373 - mean_squared_error: 0.0373
# Epoch 90/100
# 3/3 - 0s - loss: 0.0312 - mean_squared_error: 0.0312
# Epoch 91/100
# 3/3 - 0s - loss: 0.0176 - mean_squared_error: 0.0176
# Epoch 92/100
# 3/3 - 0s - loss: 0.0115 - mean_squared_error: 0.0115
# Epoch 93/100
# 3/3 - 0s - loss: 0.0130 - mean_squared_error: 0.0130
# Epoch 94/100
# 3/3 - 0s - loss: 0.0135 - mean_squared_error: 0.0135
# Epoch 95/100
# 3/3 - 0s - loss: 0.0123 - mean_squared_error: 0.0123
# Epoch 96/100
# 3/3 - 0s - loss: 0.0104 - mean_squared_error: 0.0104
# Epoch 97/100
# 3/3 - 0s - loss: 0.0085 - mean_squared_error: 0.0085
# Epoch 98/100
# 3/3 - 0s - loss: 0.0077 - mean_squared_error: 0.0077
# Epoch 99/100
# 3/3 - 0s - loss: 0.0073 - mean_squared_error: 0.0073
# Epoch 100/100
# 3/3 - 0s - loss: 0.0068 - mean_squared_error: 0.0068

# %%
# Compute Permutation and scoring
os.environ['PYTHONHASHSEED'] = str(42)
np.random.seed(42)
random.seed(42)

def dnn():
    """Compute the scores for features"""
    final_score = []
    shuff_pred = []

    for i, col in enumerate(X_test.columns):
        # shuffle column
        shuff_test = scaled_test.copy()
        shuff_test[:, i] = np.random.permutation(shuff_test[:, i])

        # compute score
        score = mean_absolute_error(y_test, reverse_target(model.predict(shuff_test).ravel(), mean_train, std_train))
        shuff_pred.append(reverse_target(model.predict(shuff_test).ravel(), mean_train, std_train))
        final_score.append(score)

    final_score = np.asarray(final_score)
    # Normalize to match scale 0-1.
    final_score = [score*20 for score in final_score]
    
    return final_score

# %%
# Permutation Importance Report
#  Plot feature importances predicted by Deep Neural Network while plotting it against features.
plot_features("dnn")

# %%
#Find average of the feature importances predicted by Random Forest, XGBoost and Neural Network
# while plotting it against features.
plot_features("average")

# %%
# Compare train and test accuracies to ensure that model is not overfitting on the training set.
_, rf_train_accuracy, rf_test_accuracy = random_forest()
_, xgboost_train_accuracy, xgboost_test_accuracy = xg_boost()

N = 2
rf_accuracies = (rf_train_accuracy, rf_test_accuracy)
print("Random Forest train accuracy: %0.3f" % rf_train_accuracy)
print("Random Forest test accuracy: %0.3f" % rf_test_accuracy)

xgboost_accuracies = (xgboost_train_accuracy, xgboost_test_accuracy)
print("XGBoost train accuracy: %0.3f" % xgboost_train_accuracy)
print("XGBoost test accuracy: %0.3f" % xgboost_test_accuracy)

ind = np.arange(N)
width = 0.1
plt.bar(ind, rf_accuracies, width, label='Random Forest')
plt.bar(ind + width, xgboost_accuracies, width, label='XGBoost')

plt.ylabel('Accuracy')
plt.title('Accuracies by algorithms')

plt.xticks(ind + width / 2, ('Train Accuracy', 'Test Accuracy'))
plt.legend(loc='best')
plt.show()
# Out:
# Random Forest train accuracy: 0.992
# Random Forest test accuracy: 0.856
# XGBoost train accuracy: 1.000
# XGBoost test accuracy: 0.897

# %%
# Prediction error of Deep Neural Network on test set to see if the model is not overfitting
real_pred = reverse_target(model.predict(scaled_test).ravel(), mean_train, std_train)
MAE = mean_absolute_error(y_test, real_pred)
print(MAE)
# Out:
# 0.005436865376309908

# %%
#    Just like the combined state model, all the machine learning algorithms perform very well
#    when Georgia is selected. It has similar results with the combined states largely
#    due to the fact that majority of the Census Tracts come from Georgia. Median income is the most
#    important feature.
